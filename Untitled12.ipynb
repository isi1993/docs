# %% [markdown]
# <a href="https://colab.research.google.com/github/isi1993/docs/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/sales_revenue_data.csv')
df
# Out:
#       Transaction ID        Date Customer Name     Product  Quantity Sold  \
# 0                  1  2023-02-24         David     Printer             10
# 1                  2  2023-01-19       Charlie  Smartphone              3
# 2                  3  2023-06-14         David    Keyboard              6
# 3                  4  2023-03-28         Alice  Smartphone              6
# 4                  5  2023-01-05       Charlie       Mouse              1
# ...              ...         ...           ...         ...            ...
# 9995            9996  2023-11-12         David  Smartphone              2
# 9996            9997  2023-05-13       Charlie     Monitor              2
# 9997            9998  2023-03-21          Jack       Mouse              9
# 9998            9999  2023-04-28           Ivy     Printer              9
# 9999           10000  2023-01-17           Bob      Tablet              6
#
#       Price per Unit  Total Revenue
# 0             592.62        5926.20
# ...

# %%
df.head()
# Out:
#    Transaction ID        Date Customer Name     Product  Quantity Sold  \
# 0               1  2023-02-24         David     Printer             10
# 1               2  2023-01-19       Charlie  Smartphone              3
# 2               3  2023-06-14         David    Keyboard              6
# 3               4  2023-03-28         Alice  Smartphone              6
# 4               5  2023-01-05       Charlie       Mouse              1
#
#    Price per Unit  Total Revenue
# 0          592.62        5926.20
# 1          203.90         611.70
# 2          388.56        2331.36
# 3          549.88        3299.28
# 4         1441.22        1441.22

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)

# %%
df[df['Quantity Sold'] >= 10]
# Out:
#       Transaction ID        Date Customer Name     Product  Quantity Sold  \
# 0                  1  2023-02-24         David     Printer             10
# 19                20  2023-10-13         Alice    Keyboard             10
# 20                21  2023-04-07           Ivy    Keyboard             10
# 21                22  2023-08-23           Eve    Keyboard             10
# 29                30  2023-03-17           Bob      Tablet             10
# ...              ...         ...           ...         ...            ...
# 9970            9971  2023-10-05         Frank  Smartwatch             10
# 9980            9981  2023-12-30       Charlie       Mouse             10
# 9984            9985  2023-04-04         Grace  Smartwatch             10
# 9986            9987  2023-04-09         Frank     Printer             10
# 9993            9994  2023-09-18       Charlie  Smartphone             10
#
#       Price per Unit  Total Revenue
# 0             592.62         5926.2
# ...

# %%
specific_product = ['Smartwatch','Printer', 'Mouse']
df[df['Product'].isin(specific_product)]
# Out:
#       Transaction ID        Date Customer Name     Product  Quantity Sold  \
# 0                  1  2023-02-24         David     Printer             10
# 4                  5  2023-01-05       Charlie       Mouse              1
# 8                  9  2023-01-20         Frank  Smartwatch              5
# 13                14  2023-10-11           Eve       Mouse              5
# 14                15  2023-11-21       Charlie  Smartwatch              9
# ...              ...         ...           ...         ...            ...
# 9986            9987  2023-04-09         Frank     Printer             10
# 9989            9990  2023-02-24           Eve       Mouse              3
# 9991            9992  2023-10-26         David       Mouse              3
# 9997            9998  2023-03-21          Jack       Mouse              9
# 9998            9999  2023-04-28           Ivy     Printer              9
#
#       Price per Unit  Total Revenue
# 0             592.62        5926.20
# ...

# %%
df[df['Product'].str.contains('smartwatch')]
df
# Out:
#       Transaction ID        Date Customer Name     Product  Quantity Sold  \
# 0                  1  2023-02-24         David     Printer             10
# 1                  2  2023-01-19       Charlie  Smartphone              3
# 2                  3  2023-06-14         David    Keyboard              6
# 3                  4  2023-03-28         Alice  Smartphone              6
# 4                  5  2023-01-05       Charlie       Mouse              1
# ...              ...         ...           ...         ...            ...
# 9995            9996  2023-11-12         David  Smartphone              2
# 9996            9997  2023-05-13       Charlie     Monitor              2
# 9997            9998  2023-03-21          Jack       Mouse              9
# 9998            9999  2023-04-28           Ivy     Printer              9
# 9999           10000  2023-01-17           Bob      Tablet              6
#
#       Price per Unit  Total Revenue
# 0             592.62        5926.20
# ...

# %%
df[df['Customer Name'].str.contains('David')]
df[df['Customer Name'].str.contains('David')]
# Out:
#       Transaction ID        Date Customer Name     Product  Quantity Sold  \
# 0                  1  2023-02-24         David     Printer             10
# 2                  3  2023-06-14         David    Keyboard              6
# 9                 10  2023-11-04         David      Camera              2
# 23                24  2023-04-17         David      Tablet              3
# 51                52  2023-07-08         David  Smartwatch             10
# ...              ...         ...           ...         ...            ...
# 9963            9964  2023-10-31         David      Tablet              8
# 9974            9975  2023-06-07         David  Smartwatch              2
# 9982            9983  2023-03-21         David      Camera              4
# 9991            9992  2023-10-26         David       Mouse              3
# 9995            9996  2023-11-12         David  Smartphone              2
#
#       Price per Unit  Total Revenue
# 0             592.62        5926.20
# ...

# %%
df[df['Product'].str.contains('Smartwatch', 'Camera')]
df[df['Product'].str.contains('Smartwatch', 'Camera')]
# Out:
#       Transaction ID        Date Customer Name     Product  Quantity Sold  \
# 8                  9  2023-01-20         Frank  Smartwatch              5
# 14                15  2023-11-21       Charlie  Smartwatch              9
# 26                27  2023-12-05          Jack  Smartwatch              2
# 28                29  2023-12-09         Alice  Smartwatch              1
# 31                32  2023-02-24         Grace  Smartwatch              2
# ...              ...         ...           ...         ...            ...
# 9941            9942  2023-05-01         Frank  Smartwatch              4
# 9966            9967  2023-09-29           Bob  Smartwatch              3
# 9970            9971  2023-10-05         Frank  Smartwatch             10
# 9974            9975  2023-06-07         David  Smartwatch              2
# 9984            9985  2023-04-04         Grace  Smartwatch             10
#
#       Price per Unit  Total Revenue
# 8            1502.08        7510.40
# ...

# %%
df2= df.set_index('Product')
df2
# Out:
#             Transaction ID        Date Customer Name  Quantity Sold  \
# Product
# Printer                  1  2023-02-24         David             10
# Smartphone               2  2023-01-19       Charlie              3
# Keyboard                 3  2023-06-14         David              6
# Smartphone               4  2023-03-28         Alice              6
# Mouse                    5  2023-01-05       Charlie              1
# ...                    ...         ...           ...            ...
# Smartphone            9996  2023-11-12         David              2
# Monitor               9997  2023-05-13       Charlie              2
# Mouse                 9998  2023-03-21          Jack              9
# Printer               9999  2023-04-28           Ivy              9
# Tablet               10000  2023-01-17           Bob              6
#
#             Price per Unit  Total Revenue
# Product
# Printer             592.62        5926.20
# Smartphone          203.90         611.70
# ...

# %%
df2.filter(items = ['Date', 'Product','Customer Name', 'Quantity Sold'], axis = 1)
# Out:
#                   Date Customer Name  Quantity Sold
# Product
# Printer     2023-02-24         David             10
# Smartphone  2023-01-19       Charlie              3
# Keyboard    2023-06-14         David              6
# Smartphone  2023-03-28         Alice              6
# Mouse       2023-01-05       Charlie              1
# ...                ...           ...            ...
# Smartphone  2023-11-12         David              2
# Monitor     2023-05-13       Charlie              2
# Mouse       2023-03-21          Jack              9
# Printer     2023-04-28           Ivy              9
# Tablet      2023-01-17           Bob              6
#
# [10000 rows x 3 columns]

# %%
df2.filter(items = ['Smartphone'], axis = 1)
df2.filter
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df2.filter(like = 'smartwatch', axis = 1)
df2.filter(like = 'smartwatch', axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df2.loc['Smartphone']
# Out:
#             Transaction ID        Date Customer Name  Quantity Sold  \
# Product
# Smartphone               2  2023-01-19       Charlie              3
# Smartphone               4  2023-03-28         Alice              6
# Smartphone              12  2023-11-24           Eve              7
# Smartphone              16  2023-09-07           Bob              9
# Smartphone              17  2023-01-15         Grace              1
# ...                    ...         ...           ...            ...
# Smartphone            9966  2023-09-18       Charlie              5
# Smartphone            9972  2023-11-23       Charlie              5
# Smartphone            9978  2023-04-11           Ivy              3
# Smartphone            9994  2023-09-18       Charlie             10
# Smartphone            9996  2023-11-12         David              2
#
#             Price per Unit  Total Revenue
# Product
# Smartphone          203.90         611.70
# Smartphone          549.88        3299.28
# ...

# %%
df2.iloc[9999]
# Out:
# Transaction ID         10000
# Date              2023-01-17
# Customer Name            Bob
# Quantity Sold              6
# Price per Unit        983.34
# Total Revenue        5900.04
# Name: Tablet, dtype: object

# %%
df
# Out:
#       Transaction ID        Date Customer Name     Product  Quantity Sold  \
# 0                  1  2023-02-24         David     Printer             10
# 1                  2  2023-01-19       Charlie  Smartphone              3
# 2                  3  2023-06-14         David    Keyboard              6
# 3                  4  2023-03-28         Alice  Smartphone              6
# 4                  5  2023-01-05       Charlie       Mouse              1
# ...              ...         ...           ...         ...            ...
# 9995            9996  2023-11-12         David  Smartphone              2
# 9996            9997  2023-05-13       Charlie     Monitor              2
# 9997            9998  2023-03-21          Jack       Mouse              9
# 9998            9999  2023-04-28           Ivy     Printer              9
# 9999           10000  2023-01-17           Bob      Tablet              6
#
#       Price per Unit  Total Revenue
# 0             592.62        5926.20
# ...

# %%
df[df['Total Revenue'] > 5000].sort_values(by='Total Revenue', ascending=TRUE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-a3c34ab8e663> in <cell line: 0>()
# ----> 1 df[df['Total Revenue'] > 5000].sort_values(by='Total Revenue', ascending=TRUE)
#
# NameError: name 'TRUE' is not defined
